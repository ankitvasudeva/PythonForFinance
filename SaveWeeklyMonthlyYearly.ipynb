# %%
import pandas as pd
import numpy as np

# %%
style.use('ggplot')

# %%
df = pd.read_csv('~/Notebook/data/stocks/yf/ITC.BO.csv')

# %%
df.tail()
# Out:
#             Date    Open    High     Low   Close     Volume  Dividends  \
# 7152  2020-08-21  198.85  199.00  196.35  196.90  1259484.0        0.0
# 7153  2020-08-24  197.00  198.90  196.40  196.65   854654.0        0.0
# 7154  2020-08-25  197.00  198.25  195.05  195.55   570292.0        0.0
# 7155  2020-08-26  196.05  196.40  193.70  194.95  1200270.0        0.0
# 7156  2020-08-27  198.00  198.95  194.10  194.50   888206.0        0.0
#
#       Stock Splits
# 7152           0.0
# 7153           0.0
# 7154           0.0
# 7155           0.0
# 7156           0.0

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Week'] = df['Date'].dt.isocalendar().week

# %%
df['Month'] = df['Date'].dt.month

# %%
df['Year'] = df['Date'].dt.isocalendar().year

# %%
df_Weekly = df.groupby(['Year', 'Week']).agg({'Open':'first', 'Close':'last','High' : 'max','Low': 'min', 'Volume' :'sum'})

# %%
df_Monthly = df.groupby(['Year', 'Month']).agg({'Open':'first', 'Close':'last','High' : 'max','Low': 'min', 'Volume' :'sum'})

# %%
df_Yearly = df.groupby(['Year']).agg({'Open':'first', 'Close':'last','High' : 'max','Low': 'min', 'Volume' :'sum'})

# %%
#df_Monthly['VolPerTrade'] =df_Monthly['Volume'] / df_Monthly['Trades']

# %%
df_Yearly
# Out:
#         Open   Close    High     Low        Volume
# Year
# 1991    0.00    0.00    0.00    0.00  0.000000e+00
# 1992    0.00    0.00    0.00    0.00  0.000000e+00
# 1993    0.00    0.00    0.00    0.00  0.000000e+00
# 1994    0.00    0.00    0.00    0.00  0.000000e+00
# 1995    0.00    0.00    0.00    0.00  1.936755e+08
# 1996    0.00    0.00    0.00    0.00  8.242878e+09
# 1997    0.00    0.00    0.00    0.00  3.745702e+10
# 1998    0.00    0.00    0.00    0.00  3.653729e+10
# 1999    0.00    0.00    0.00    0.00  1.247973e+10
# 2000    0.00    0.00    0.00    0.00  8.215789e+09
# 2001    0.00    0.00    0.00    0.00  4.712153e+09
# 2002    0.00    0.02    0.03    0.00  2.085380e+09
# 2003    0.02    0.32    0.35    0.02  1.462851e+09
# 2004    0.33    3.59    3.67    0.24  1.320496e+09
# 2005    3.63   27.64   28.94    3.33  1.447169e+09
# 2006   27.74   35.88   41.40   27.23  1.111269e+09
# 2007   36.27   44.56   45.94   28.58  9.203609e+08
# ...
