# %%
import pandas as pd
import datetime as dt
import pandas_datareader.data as web
from nsepy import get_history
from matplotlib import style
from matplotlib.pyplot import plot

# %%
style.use('ggplot')

# %%
start = dt.datetime(2000,1,1)
end  = dt.datetime(2020,8,1)

# %%
df = get_history(symbol="INFY", start=start, end=end)

# %%
print(df.tail())
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2020-07-27   INFY     EQ      922.85  921.55  952.80  918.65  947.15  948.45
# 2020-07-28   INFY     EQ      948.45  946.00  967.55  941.20  960.60  962.85
# 2020-07-29   INFY     EQ      962.85  953.25  960.00  943.60  951.95  954.15
# 2020-07-30   INFY     EQ      954.15  962.00  972.65  958.75  962.15  961.45
# 2020-07-31   INFY     EQ      961.45  969.25  986.45  953.30  967.75  966.00
#
#               VWAP    Volume      Turnover    Trades  Deliverable Volume  \
# Date
# 2020-07-27  939.16  16828218  1.580444e+15  278528.0           5906860.0
# 2020-07-28  953.58  15819466  1.508506e+15  220010.0           5480184.0
# 2020-07-29  952.22  11152710  1.061982e+15  212215.0           4338542.0
# 2020-07-30  965.59  12492569  1.206274e+15  222807.0           5962965.0
# 2020-07-31  971.12  12704359  1.233742e+15  195979.0           3201880.0
#
#             %Deliverble
# Date
# 2020-07-27       0.3510
# 2020-07-28       0.3464
# 2020-07-29       0.3890
# 2020-07-30       0.4773
# 2020-07-31       0.2520

# %%
df['%Deliverble'].plot()
